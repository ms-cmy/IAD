# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math
import ROOT

# %%
def my_func(x, par):
    return math.sin(x[0] * 2) / x[0]

# %%
myobj = ROOT.TF1("myfunc", my_func, 0.1, 10, 0)
c = ROOT.TCanvas("c", "Canvas", 800, 600)
myobj.Draw()
c.Draw()

# %% [markdown]
# [Gráfico do código](seno.cpp)

# %%
img = mpimg.imread('seno.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# [código cpp que gerou o gráfico abaixo](exemplo_1.cpp)

# %%
img = mpimg.imread('exercicio_1_em_cpp.png')
imgplot = plt.imshow(img)
plt.show()
